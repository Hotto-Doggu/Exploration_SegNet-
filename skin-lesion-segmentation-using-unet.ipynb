# %% [markdown]
# ## Importing the Libraries

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)

# Imports essenciais
import sys
import numpy as np
import pandas as pd
import glob
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

# Camadas e componentes do TensorFlow/Keras
from tensorflow.keras.layers import (
    Activation, Dense, BatchNormalization, Dropout, 
    Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, 
    Input, Reshape, Layer
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

# Processamento de imagens e visualização
from PIL import Image, ImageEnhance, ImageFilter
import matplotlib.pyplot as plt
# %matplotlib inline

# Habilitar mixed precision training
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')


# Configurações de warnings e reprodução
filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)

# --------------------------
# Configuração da GPU (Opcional)
# --------------------------
import os
# Herdar variáveis do ambiente Conda
os.environ['LD_LIBRARY_PATH'] = os.path.join(os.environ['CONDA_PREFIX'], 'lib') + ':' + os.environ.get('LD_LIBRARY_PATH', '')
os.environ['XLA_FLAGS'] = f'--xla_gpu_cuda_data_dir={os.environ["CONDA_PREFIX"]}'

# Redundância para garantia
os.environ['CUDA_HOME'] = os.environ['CONDA_PREFIX']

# Configurar crescimento de memória (ajuste conforme sua VRAM)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.set_logical_device_configuration(
            gpus[0],
            [tf.config.LogicalDeviceConfiguration(memory_limit=4096)]  # 4 GB
        )
    except RuntimeError as e:
        print(e)
else:
    print("Nenhuma GPU detectada!")

# --------------------------
# Verificação do Ambiente
# --------------------------
print("\n=== Versões ===")
print("TensorFlow:", tf.__version__)
print("Python:", sys.version)
print("\n=== Status da GPU ===")
print("GPUs Físicas:", tf.config.list_physical_devices('GPU'))
print("GPUs Lógicas:", tf.config.list_logical_devices('GPU'))

# Teste de operação na GPU
if tf.config.list_physical_devices('GPU'):
    device_name = tf.test.gpu_device_name()
    print(f"\nDispositivo GPU em uso: {device_name}")
    with tf.device(device_name):
        a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
        b = tf.constant([[1.0, 1.0], [0.0, 1.0]])
        c = tf.matmul(a, b)
        print("\nTeste de operação na GPU:", c.numpy())
else:
    print("\nGPU não detectada!")

# !ldd $CONDA_PREFIX/lib/python3.10/site-packages/tensorflow/libtensorflow_framework.so.2 | grep -E 'cuda|cupti|cudnn'
# Out:
# 2025-03-25 22:35:00.540710: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-25 22:35:00.700772: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Nenhuma GPU detectada!
#
# === Versões ===
# TensorFlow: 2.18.0
# Python: 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
#
# === Status da GPU ===
# GPUs Físicas: []
# GPUs Lógicas: []
#
# GPU não detectada!

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
# Função de Redimensionamento - ANTIALIAS --> LANCZOS em versões mais recentes
def resize(filename, size=(224, 224)):
    im = Image.open(filename)
    im_resized = im.resize(size, Image.LANCZOS)
    return (im_resized)

# %%
filelist_trainx_ph2 = sorted(glob.glob('ph2_dataset/trainx/*.bmp'), key=numericalSort)
filelist_trainy_ph2 = sorted(glob.glob('ph2_dataset/trainy/*.bmp'), key=numericalSort)
# Redimensionamento das Imagens
X_train_ph2_resized = [resize(fname) for fname in filelist_trainx_ph2]
Y_train_ph2_resized = [resize(fname) for fname in filelist_trainy_ph2]
X_train = np.array([np.array(img) for img in X_train_ph2_resized])
Y_train = np.array([np.array(img).astype(np.float32)/255 for img in Y_train_ph2_resized])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    y_true = K.cast(y_true, 'float16')
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# > ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/unet_arch.png)

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_data_format() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    if K.image_data_format() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# ### For 1 epoch

# %%
model, hist = UNET_224(1, 'unet_1_epoch.h5')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "UNET_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_92 (Conv2D)          (None, 224, 224, 32)         896       ['input_6[0][0]']
#
#  batch_normalization_88 (Ba  (None, 224, 224, 32)         128       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  activation_92 (Activation)  (None, 224, 224, 32)         0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_93 (Conv2D)          (None, 224, 224, 32)         9248      ['activation_92[0][0]']
#
#  batch_normalization_89 (Ba  (None, 224, 224, 32)         128       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 224, 224, 32)         0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  spatial_dropout2d_44 (Spat  (None, 224, 224, 32)         0         ['activation_93[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_20 (MaxPooli  (None, 112, 112, 32)         0         ['spatial_dropout2d_44[0][0]']
#  ng2D)
#
#  conv2d_94 (Conv2D)          (None, 112, 112, 64)         18496     ['max_pooling2d_20[0][0]']
#
#  batch_normalization_90 (Ba  (None, 112, 112, 64)         256       ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 112, 112, 64)         36928     ['activation_94[0][0]']
#
#  batch_normalization_91 (Ba  (None, 112, 112, 64)         256       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  spatial_dropout2d_45 (Spat  (None, 112, 112, 64)         0         ['activation_95[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_21 (MaxPooli  (None, 56, 56, 64)           0         ['spatial_dropout2d_45[0][0]']
#  ng2D)
#
#  conv2d_96 (Conv2D)          (None, 56, 56, 128)          73856     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_92 (Ba  (None, 56, 56, 128)          512       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_97 (Conv2D)          (None, 56, 56, 128)          147584    ['activation_96[0][0]']
#
#  batch_normalization_93 (Ba  (None, 56, 56, 128)          512       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  spatial_dropout2d_46 (Spat  (None, 56, 56, 128)          0         ['activation_97[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_22 (MaxPooli  (None, 28, 28, 128)          0         ['spatial_dropout2d_46[0][0]']
#  ng2D)
#
#  conv2d_98 (Conv2D)          (None, 28, 28, 256)          295168    ['max_pooling2d_22[0][0]']
#
#  batch_normalization_94 (Ba  (None, 28, 28, 256)          1024      ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_99 (Conv2D)          (None, 28, 28, 256)          590080    ['activation_98[0][0]']
#
#  batch_normalization_95 (Ba  (None, 28, 28, 256)          1024      ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_99 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  spatial_dropout2d_47 (Spat  (None, 28, 28, 256)          0         ['activation_99[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_23 (MaxPooli  (None, 14, 14, 256)          0         ['spatial_dropout2d_47[0][0]']
#  ng2D)
#
#  conv2d_100 (Conv2D)         (None, 14, 14, 512)          1180160   ['max_pooling2d_23[0][0]']
#
#  batch_normalization_96 (Ba  (None, 14, 14, 512)          2048      ['conv2d_100[0][0]']
#  tchNormalization)
#
#  activation_100 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_96[0][0]
#  )                                                                  ']
#
#  conv2d_101 (Conv2D)         (None, 14, 14, 512)          2359808   ['activation_100[0][0]']
#
#  batch_normalization_97 (Ba  (None, 14, 14, 512)          2048      ['conv2d_101[0][0]']
#  tchNormalization)
#
#  activation_101 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_97[0][0]
#  )                                                                  ']
#
#  spatial_dropout2d_48 (Spat  (None, 14, 14, 512)          0         ['activation_101[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_24 (MaxPooli  (None, 7, 7, 512)            0         ['spatial_dropout2d_48[0][0]']
#  ng2D)
#
#  conv2d_102 (Conv2D)         (None, 7, 7, 1024)           4719616   ['max_pooling2d_24[0][0]']
#
#  batch_normalization_98 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_102[0][0]']
#  tchNormalization)
#
#  activation_102 (Activation  (None, 7, 7, 1024)           0         ['batch_normalization_98[0][0]
#  )                                                                  ']
#
#  conv2d_103 (Conv2D)         (None, 7, 7, 1024)           9438208   ['activation_102[0][0]']
#
#  batch_normalization_99 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_103[0][0]']
#  tchNormalization)
#
#  activation_103 (Activation  (None, 7, 7, 1024)           0         ['batch_normalization_99[0][0]
#  )                                                                  ']
#
#  spatial_dropout2d_49 (Spat  (None, 7, 7, 1024)           0         ['activation_103[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_20 (UpSampli  (None, 14, 14, 1024)         0         ['spatial_dropout2d_49[0][0]']
#  ng2D)
#
#  concatenate_20 (Concatenat  (None, 14, 14, 1536)         0         ['up_sampling2d_20[0][0]',
#  e)                                                                  'spatial_dropout2d_48[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 512)          7078400   ['concatenate_20[0][0]']
#
#  batch_normalization_100 (B  (None, 14, 14, 512)          2048      ['conv2d_104[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  conv2d_105 (Conv2D)         (None, 14, 14, 512)          2359808   ['activation_104[0][0]']
#
#  batch_normalization_101 (B  (None, 14, 14, 512)          2048      ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_50 (Spat  (None, 14, 14, 512)          0         ['activation_105[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_21 (UpSampli  (None, 28, 28, 512)          0         ['spatial_dropout2d_50[0][0]']
#  ng2D)
#
#  concatenate_21 (Concatenat  (None, 28, 28, 768)          0         ['up_sampling2d_21[0][0]',
#  e)                                                                  'spatial_dropout2d_47[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 28, 28, 256)          1769728   ['concatenate_21[0][0]']
#
#  batch_normalization_102 (B  (None, 28, 28, 256)          1024      ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_107 (Conv2D)         (None, 28, 28, 256)          590080    ['activation_106[0][0]']
#
#  batch_normalization_103 (B  (None, 28, 28, 256)          1024      ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_51 (Spat  (None, 28, 28, 256)          0         ['activation_107[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_22 (UpSampli  (None, 56, 56, 256)          0         ['spatial_dropout2d_51[0][0]']
#  ng2D)
#
#  concatenate_22 (Concatenat  (None, 56, 56, 384)          0         ['up_sampling2d_22[0][0]',
#  e)                                                                  'spatial_dropout2d_46[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 56, 56, 128)          442496    ['concatenate_22[0][0]']
#
#  batch_normalization_104 (B  (None, 56, 56, 128)          512       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  conv2d_109 (Conv2D)         (None, 56, 56, 128)          147584    ['activation_108[0][0]']
#
#  batch_normalization_105 (B  (None, 56, 56, 128)          512       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_52 (Spat  (None, 56, 56, 128)          0         ['activation_109[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_23 (UpSampli  (None, 112, 112, 128)        0         ['spatial_dropout2d_52[0][0]']
#  ng2D)
#
#  concatenate_23 (Concatenat  (None, 112, 112, 192)        0         ['up_sampling2d_23[0][0]',
#  e)                                                                  'spatial_dropout2d_45[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 112, 112, 64)         110656    ['concatenate_23[0][0]']
#
#  batch_normalization_106 (B  (None, 112, 112, 64)         256       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  conv2d_111 (Conv2D)         (None, 112, 112, 64)         36928     ['activation_110[0][0]']
#
#  batch_normalization_107 (B  (None, 112, 112, 64)         256       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_111 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_53 (Spat  (None, 112, 112, 64)         0         ['activation_111[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_24 (UpSampli  (None, 224, 224, 64)         0         ['spatial_dropout2d_53[0][0]']
#  ng2D)
#
#  concatenate_24 (Concatenat  (None, 224, 224, 96)         0         ['up_sampling2d_24[0][0]',
#  e)                                                                  'spatial_dropout2d_44[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 224, 224, 32)         27680     ['concatenate_24[0][0]']
#
#  batch_normalization_108 (B  (None, 224, 224, 32)         128       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_112 (Activation  (None, 224, 224, 32)         0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  conv2d_113 (Conv2D)         (None, 224, 224, 32)         9248      ['activation_112[0][0]']
#
#  batch_normalization_109 (B  (None, 224, 224, 32)         128       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 224, 224, 32)         0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_54 (Spat  (None, 224, 224, 32)         0         ['activation_113[0][0]']
#  ialDropout2D)
#
#  conv2d_114 (Conv2D)         (None, 224, 224, 1)          33        ['spatial_dropout2d_54[0][0]']
#
#  activation_114 (Activation  (None, 224, 224, 1)          0         ['conv2d_114[0][0]']
#  )
#
#  reshape_4 (Reshape)         (None, 224, 224)             0         ['activation_114[0][0]']
#
# ==================================================================================================
# Total params: 31466753 (120.04 MB)
# Trainable params: 31454721 (119.99 MB)
# Non-trainable params: 12032 (47.00 KB)
# __________________________________________________________________________________________________
# 2025-03-25 13:46:50.481455: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2025-03-25 13:47:07.827315: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5a18815d70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-03-25 13:47:07.827356: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-03-25 13:47:07.934720: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-25 13:47:08.662883: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/20 [==============================] - 34s 352ms/step - loss: 0.2321 - iou: 0.7679 - dice_coe: 0.0011 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.7269 - val_loss: nan - val_iou: nan - val_dice_coe: nan - val_precision: nan - val_recall: nan - val_accuracy: 0.0000e+00

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
dropout_val=0.50
if K.image_data_format() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model_0.load_weights('unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 20/20 [==============================] - 2s 76ms/step - loss: nan - iou: nan - dice_coe: nan - precision: nan - recall: nan - accuracy: 0.0000e+00
# ________________________
# IOU:       |   nan  |
# Dice Coef: |   nan  |
# Precision: |   nan  |
# Recall:    |   nan  |
# Accuracy:  |   0.00  |
# Loss:      |   nan  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 3/3 [==============================] - 1s 70ms/step - loss: nan - iou: nan - dice_coe: nan - precision: nan - recall: nan - accuracy: 0.0000e+00
# ________________________
# IOU:       |   nan  |
# Dice Coef: |   nan  |
# Precision: |   nan  |
# Recall:    |   nan  |
# Accuracy:  |   0.00  |
# Loss:      |   nan  |
# ________________________
#
# -------------On validation Set---------------------
#
# 5/5 [==============================] - 0s 75ms/step - loss: nan - iou: nan - dice_coe: nan - precision: nan - recall: nan - accuracy: 0.0000e+00
# ________________________
# IOU:       |   nan  |
# Dice Coef: |   nan  |
# Precision: |   nan  |
# Recall:    |   nan  |
# Accuracy:  |   0.00  |
# Loss:      |   nan  |
# ________________________

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "UNET_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_138 (Conv2D)         (None, 224, 224, 32)         896       ['input_8[0][0]']
#
#  batch_normalization_132 (B  (None, 224, 224, 32)         128       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 224, 224, 32)         0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 224, 224, 32)         9248      ['activation_138[0][0]']
#
#  batch_normalization_133 (B  (None, 224, 224, 32)         128       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 224, 224, 32)         0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_66 (Spat  (None, 224, 224, 32)         0         ['activation_139[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_30 (MaxPooli  (None, 112, 112, 32)         0         ['spatial_dropout2d_66[0][0]']
#  ng2D)
#
#  conv2d_140 (Conv2D)         (None, 112, 112, 64)         18496     ['max_pooling2d_30[0][0]']
#
#  batch_normalization_134 (B  (None, 112, 112, 64)         256       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_140 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  conv2d_141 (Conv2D)         (None, 112, 112, 64)         36928     ['activation_140[0][0]']
#
#  batch_normalization_135 (B  (None, 112, 112, 64)         256       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_141 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_67 (Spat  (None, 112, 112, 64)         0         ['activation_141[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_31 (MaxPooli  (None, 56, 56, 64)           0         ['spatial_dropout2d_67[0][0]']
#  ng2D)
#
#  conv2d_142 (Conv2D)         (None, 56, 56, 128)          73856     ['max_pooling2d_31[0][0]']
#
#  batch_normalization_136 (B  (None, 56, 56, 128)          512       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  activation_142 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  conv2d_143 (Conv2D)         (None, 56, 56, 128)          147584    ['activation_142[0][0]']
#
#  batch_normalization_137 (B  (None, 56, 56, 128)          512       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_143 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_68 (Spat  (None, 56, 56, 128)          0         ['activation_143[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_32 (MaxPooli  (None, 28, 28, 128)          0         ['spatial_dropout2d_68[0][0]']
#  ng2D)
#
#  conv2d_144 (Conv2D)         (None, 28, 28, 256)          295168    ['max_pooling2d_32[0][0]']
#
#  batch_normalization_138 (B  (None, 28, 28, 256)          1024      ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_144 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 28, 28, 256)          590080    ['activation_144[0][0]']
#
#  batch_normalization_139 (B  (None, 28, 28, 256)          1024      ['conv2d_145[0][0]']
#  atchNormalization)
#
#  activation_145 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_69 (Spat  (None, 28, 28, 256)          0         ['activation_145[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_33 (MaxPooli  (None, 14, 14, 256)          0         ['spatial_dropout2d_69[0][0]']
#  ng2D)
#
#  conv2d_146 (Conv2D)         (None, 14, 14, 512)          1180160   ['max_pooling2d_33[0][0]']
#
#  batch_normalization_140 (B  (None, 14, 14, 512)          2048      ['conv2d_146[0][0]']
#  atchNormalization)
#
#  activation_146 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_147 (Conv2D)         (None, 14, 14, 512)          2359808   ['activation_146[0][0]']
#
#  batch_normalization_141 (B  (None, 14, 14, 512)          2048      ['conv2d_147[0][0]']
#  atchNormalization)
#
#  activation_147 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_70 (Spat  (None, 14, 14, 512)          0         ['activation_147[0][0]']
#  ialDropout2D)
#
#  max_pooling2d_34 (MaxPooli  (None, 7, 7, 512)            0         ['spatial_dropout2d_70[0][0]']
#  ng2D)
#
#  conv2d_148 (Conv2D)         (None, 7, 7, 1024)           4719616   ['max_pooling2d_34[0][0]']
#
#  batch_normalization_142 (B  (None, 7, 7, 1024)           4096      ['conv2d_148[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 7, 7, 1024)           0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  conv2d_149 (Conv2D)         (None, 7, 7, 1024)           9438208   ['activation_148[0][0]']
#
#  batch_normalization_143 (B  (None, 7, 7, 1024)           4096      ['conv2d_149[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 7, 7, 1024)           0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_71 (Spat  (None, 7, 7, 1024)           0         ['activation_149[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_30 (UpSampli  (None, 14, 14, 1024)         0         ['spatial_dropout2d_71[0][0]']
#  ng2D)
#
#  concatenate_30 (Concatenat  (None, 14, 14, 1536)         0         ['up_sampling2d_30[0][0]',
#  e)                                                                  'spatial_dropout2d_70[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 14, 14, 512)          7078400   ['concatenate_30[0][0]']
#
#  batch_normalization_144 (B  (None, 14, 14, 512)          2048      ['conv2d_150[0][0]']
#  atchNormalization)
#
#  activation_150 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_144[0][0
#  )                                                                  ]']
#
#  conv2d_151 (Conv2D)         (None, 14, 14, 512)          2359808   ['activation_150[0][0]']
#
#  batch_normalization_145 (B  (None, 14, 14, 512)          2048      ['conv2d_151[0][0]']
#  atchNormalization)
#
#  activation_151 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_145[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_72 (Spat  (None, 14, 14, 512)          0         ['activation_151[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_31 (UpSampli  (None, 28, 28, 512)          0         ['spatial_dropout2d_72[0][0]']
#  ng2D)
#
#  concatenate_31 (Concatenat  (None, 28, 28, 768)          0         ['up_sampling2d_31[0][0]',
#  e)                                                                  'spatial_dropout2d_69[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 28, 28, 256)          1769728   ['concatenate_31[0][0]']
#
#  batch_normalization_146 (B  (None, 28, 28, 256)          1024      ['conv2d_152[0][0]']
#  atchNormalization)
#
#  activation_152 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_146[0][0
#  )                                                                  ]']
#
#  conv2d_153 (Conv2D)         (None, 28, 28, 256)          590080    ['activation_152[0][0]']
#
#  batch_normalization_147 (B  (None, 28, 28, 256)          1024      ['conv2d_153[0][0]']
#  atchNormalization)
#
#  activation_153 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_147[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_73 (Spat  (None, 28, 28, 256)          0         ['activation_153[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_32 (UpSampli  (None, 56, 56, 256)          0         ['spatial_dropout2d_73[0][0]']
#  ng2D)
#
#  concatenate_32 (Concatenat  (None, 56, 56, 384)          0         ['up_sampling2d_32[0][0]',
#  e)                                                                  'spatial_dropout2d_68[0][0]']
#
#  conv2d_154 (Conv2D)         (None, 56, 56, 128)          442496    ['concatenate_32[0][0]']
#
#  batch_normalization_148 (B  (None, 56, 56, 128)          512       ['conv2d_154[0][0]']
#  atchNormalization)
#
#  activation_154 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_155 (Conv2D)         (None, 56, 56, 128)          147584    ['activation_154[0][0]']
#
#  batch_normalization_149 (B  (None, 56, 56, 128)          512       ['conv2d_155[0][0]']
#  atchNormalization)
#
#  activation_155 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_74 (Spat  (None, 56, 56, 128)          0         ['activation_155[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_33 (UpSampli  (None, 112, 112, 128)        0         ['spatial_dropout2d_74[0][0]']
#  ng2D)
#
#  concatenate_33 (Concatenat  (None, 112, 112, 192)        0         ['up_sampling2d_33[0][0]',
#  e)                                                                  'spatial_dropout2d_67[0][0]']
#
#  conv2d_156 (Conv2D)         (None, 112, 112, 64)         110656    ['concatenate_33[0][0]']
#
#  batch_normalization_150 (B  (None, 112, 112, 64)         256       ['conv2d_156[0][0]']
#  atchNormalization)
#
#  activation_156 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_150[0][0
#  )                                                                  ]']
#
#  conv2d_157 (Conv2D)         (None, 112, 112, 64)         36928     ['activation_156[0][0]']
#
#  batch_normalization_151 (B  (None, 112, 112, 64)         256       ['conv2d_157[0][0]']
#  atchNormalization)
#
#  activation_157 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_151[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_75 (Spat  (None, 112, 112, 64)         0         ['activation_157[0][0]']
#  ialDropout2D)
#
#  up_sampling2d_34 (UpSampli  (None, 224, 224, 64)         0         ['spatial_dropout2d_75[0][0]']
#  ng2D)
#
#  concatenate_34 (Concatenat  (None, 224, 224, 96)         0         ['up_sampling2d_34[0][0]',
#  e)                                                                  'spatial_dropout2d_66[0][0]']
#
#  conv2d_158 (Conv2D)         (None, 224, 224, 32)         27680     ['concatenate_34[0][0]']
#
#  batch_normalization_152 (B  (None, 224, 224, 32)         128       ['conv2d_158[0][0]']
#  atchNormalization)
#
#  activation_158 (Activation  (None, 224, 224, 32)         0         ['batch_normalization_152[0][0
#  )                                                                  ]']
#
#  conv2d_159 (Conv2D)         (None, 224, 224, 32)         9248      ['activation_158[0][0]']
#
#  batch_normalization_153 (B  (None, 224, 224, 32)         128       ['conv2d_159[0][0]']
#  atchNormalization)
#
#  activation_159 (Activation  (None, 224, 224, 32)         0         ['batch_normalization_153[0][0
#  )                                                                  ]']
#
#  spatial_dropout2d_76 (Spat  (None, 224, 224, 32)         0         ['activation_159[0][0]']
#  ialDropout2D)
#
#  conv2d_160 (Conv2D)         (None, 224, 224, 1)          33        ['spatial_dropout2d_76[0][0]']
#
#  activation_160 (Activation  (None, 224, 224, 1)          0         ['conv2d_160[0][0]']
#  )
#
#  reshape_6 (Reshape)         (None, 224, 224)             0         ['activation_160[0][0]']
#
# ==================================================================================================
# Total params: 31466753 (120.04 MB)
# Trainable params: 31454721 (119.99 MB)
# Non-trainable params: 12032 (47.00 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 37s 1s/step - loss: 0.2076 - iou: 0.7925 - dice_coe: 0.0011 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.7327 - val_loss: 0.6875 - val_iou: 0.3122 - val_dice_coe: 9.7636e-04 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.0048
# Epoch 2/100
# 20/20 [==============================] - 25s 1s/step - loss: 0.1070 - iou: 0.8930 - dice_coe: 0.0014 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8592 - val_loss: nan - val_iou: nan - val_dice_coe: nan - val_precision: nan - val_recall: nan - val_accuracy: 0.1177
# Epoch 3/100
# 20/20 [==============================] - 25s 1s/step - loss: 0.0650 - iou: 0.9350 - dice_coe: 0.0017 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8747 - val_loss: 5.2691e-06 - val_iou: 1.0000 - val_dice_coe: 0.2118 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 4/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0368 - iou: 0.9632 - dice_coe: 0.0019 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8896 - val_loss: 5.6148e-06 - val_iou: 1.0000 - val_dice_coe: 0.2069 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 5/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.0226 - iou: 0.9775 - dice_coe: 0.0024 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8901 - val_loss: 6.3022e-04 - val_iou: 0.9994 - val_dice_coe: 0.0530 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 6/100
# 20/20 [==============================] - 25s 1s/step - loss: 0.0197 - iou: 0.9803 - dice_coe: 0.0025 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8917 - val_loss: 0.0050 - val_iou: 0.9950 - val_dice_coe: 0.0059 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 7/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0172 - iou: 0.9828 - dice_coe: 0.0026 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8893 - val_loss: 0.0087 - val_iou: 0.9913 - val_dice_coe: 0.0032 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 8/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.0146 - iou: 0.9854 - dice_coe: 0.0027 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8908 - val_loss: 0.0083 - val_iou: 0.9917 - val_dice_coe: 0.0029 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 9/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0111 - iou: 0.9889 - dice_coe: 0.0031 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 0.0068 - val_iou: 0.9932 - val_dice_coe: 0.0030 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 10/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0128 - iou: 0.9873 - dice_coe: 0.0032 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8913 - val_loss: 0.0042 - val_iou: 0.9958 - val_dice_coe: 0.0037 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 11/100
# 20/20 [==============================] - 25s 1s/step - loss: 0.0105 - iou: 0.9895 - dice_coe: 0.0035 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 0.0027 - val_iou: 0.9973 - val_dice_coe: 0.0044 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 12/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.0083 - iou: 0.9917 - dice_coe: 0.0037 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 0.0020 - val_iou: 0.9981 - val_dice_coe: 0.0049 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 13/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0087 - iou: 0.9913 - dice_coe: 0.0039 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 0.0016 - val_iou: 0.9986 - val_dice_coe: 0.0054 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 14/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0078 - iou: 0.9922 - dice_coe: 0.0041 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 0.0013 - val_iou: 0.9989 - val_dice_coe: 0.0059 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 15/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.0080 - iou: 0.9920 - dice_coe: 0.0042 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 9.6312e-04 - val_iou: 0.9991 - val_dice_coe: 0.0064 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 16/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0057 - iou: 0.9942 - dice_coe: 0.0049 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8919 - val_loss: 7.0143e-04 - val_iou: 0.9992 - val_dice_coe: 0.0068 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 17/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.0052 - iou: 0.9948 - dice_coe: 0.0047 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8918 - val_loss: 5.1785e-04 - val_iou: 0.9994 - val_dice_coe: 0.0074 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8900
# Epoch 18/100
# 18/20 [==========================>...] - ETA: 2s - loss: 0.0047 - iou: 0.9953 - dice_coe: 0.0057 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
#
# Cell In[80], line 68, in UNET_224(epochs_num, savename)
#      65 model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
#      66               , metrics=[iou, dice_coe, precision, recall, accuracy])
#      67 model.summary()
# ---> 68 hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
#      69 model.save(savename)
#      70 return model, hist
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model_1.load_weights('unet_100_epoch.h5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 model_1.load_weights('unet_100_epoch.h5')
#
# File ~/anaconda3/envs/segnet/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'unet_100_epoch.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# ![](http://)Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 20/20 [==============================] - 2s 78ms/step - loss: nan - iou: nan - dice_coe: nan - precision: nan - recall: nan - accuracy: 0.0000e+00
# ________________________
# IOU:       |   nan  |
# Dice Coef: |   nan  |
# Precision: |   nan  |
# Recall:    |   nan  |
# Accuracy:  |   0.00  |
# Loss:      |   nan  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 3/3 [==============================] - 1s 68ms/step - loss: nan - iou: nan - dice_coe: nan - precision: nan - recall: nan - accuracy: 0.0000e+00
# ________________________
# IOU:       |   nan  |
# Dice Coef: |   nan  |
# Precision: |   nan  |
# Recall:    |   nan  |
# Accuracy:  |   0.00  |
# Loss:      |   nan  |
# ________________________
#
# -------------On validation Set---------------------
#
# 5/5 [==============================] - 0s 78ms/step - loss: nan - iou: nan - dice_coe: nan - precision: nan - recall: nan - accuracy: 0.0000e+00
# ________________________
# IOU:       |   nan  |
# Dice Coef: |   nan  |
# Precision: |   nan  |
# Recall:    |   nan  |
# Accuracy:  |   0.00  |
# Loss:      |   nan  |
# ________________________

# %% [markdown]
# ### Plotting Training Stats

# %% [markdown]
# ## Visualising Predicted Lesions

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224, 224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
