# %% [markdown]
# ### Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
import tensorflow.keras.backend as K
from keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
import os
import sys

from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)


# Habilitar mixed precision training
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('float32')


# Configurar crescimento de memória (ajuste conforme sua VRAM)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.set_logical_device_configuration(
            gpus[0],
            [tf.config.LogicalDeviceConfiguration(memory_limit=4096)]  # 4 GB
        )
    except RuntimeError as e:
        print(e)
else:
    print("Nenhuma GPU detectada!")
# Out:
# 2025-03-24 22:17:55.897988: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-24 22:17:55.907033: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742865475.918749  418453 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742865475.922716  418453 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-24 22:17:55.934595: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Loading the data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %% [markdown]
# * First we will load the filenames in a list.
# * Then we will open each filename as an Image and convert it to numpy array and create list of such numpy arrays.
# * Same will be done for both Feature Images and Label Images

# %%
# Função de Redimensionamento - ANTIALIAS --> LANCZOS em versões mais recentes
def resize(filename, size = (256,192)):
    im = Image.open(filename)
    im_resized = im.resize(size, Image.LANCZOS)
    return (im_resized)

# %%
filelist_trainx_ph2 = sorted(glob.glob('ph2_dataset/trainx/*.bmp'), key=numericalSort)
filelist_trainy_ph2 = sorted(glob.glob('ph2_dataset/trainy/*.bmp'), key=numericalSort)

X_train_ph2_resized = [resize(fname) for fname in filelist_trainx_ph2]
Y_train_ph2_resized = [resize(fname) for fname in filelist_trainy_ph2]

# %%
# Conversão para Arrays Numpy
X_train_ph2 = np.array([np.array(img) for img in X_train_ph2_resized])
Y_train_ph2 = np.array([np.array(img) for img in Y_train_ph2_resized])

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(X_train_ph2[0])
plt.xlabel("Dimensions: "+str(np.array(X_train_ph2[0]).shape))
plt.subplot(1,2,2)
plt.imshow(Y_train_ph2[0], plt.cm.binary_r)
plt.xlabel("Dimensions: "+str(np.array(Y_train_ph2[0]).shape))
plt.show()

# %% [markdown]
# We can observe that the images are of dimensions **(572, 765)** so we will scale dow the images. It will also reduce the training time of the network.

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train_ph2, Y_train_ph2, test_size = 0.25, random_state = 101)

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train_ph2[0])
plt.subplot(2,4,2)
plt.imshow(X_train_ph2[3])
plt.subplot(2,4,3)
plt.imshow(X_train_ph2[54])
plt.subplot(2,4,4)
plt.imshow(X_train_ph2[77])
plt.subplot(2,4,5)
plt.imshow(X_train_ph2[100])
plt.subplot(2,4,6)
plt.imshow(X_train_ph2[125])
plt.subplot(2,4,7)
plt.imshow(X_train_ph2[130])
plt.subplot(2,4,8)
plt.imshow(X_train_ph2[149])
plt.show()

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(y_test[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(y_test[3], cmap = plt.cm.binary_r)
plt.show()

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(x_test[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(x_test[3], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![i](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    y_true = K.cast(y_true, 'float32') # Converter y_true para float32 explicitamente

    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice Coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![i](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high

# %% [markdown]
# ![i](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative

# %% [markdown]
# ![i](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation

# %% [markdown]
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return np.array(x_image), np.array(y_image.astype('int'))

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 112
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch

# %%
# Adicione isto antes de chamar model.fit()
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
#
#
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# Optimizer and Learning Rate
# * We adopt SGD optimization algorithm, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * On large datasets, SGD can converge faster than batch training because it performs updates more frequently. We can get away with this because the data often contains redundant information, so the gradient can be reasonably approximated without using the full dataset. Minibatch training can be faster than training on single data points because it can take advantage of vectorized operations to process the entire minibatch at once. The stochastic nature of online/minibatch training can also make it possible to hop out of local minima that might otherwise trap batch training.
# * The learning rate is the conventional 0.001.

# %% [markdown]
# #### Model Function

# %% [markdown]
# ![ii](https://raw.githubusercontent.com/hashbanger/PersonalStuff/master/test2.jpg)

# %% [markdown]
# * The above network is a variation of the architecture proposed [here](https://arxiv.org/pdf/1511.00561.pdf), we have customised it for our problem of lesion segmentation.
# * The advised parameters can't exactly be applied to our problem.
# * We will switch the final activation function from **Softmax** to **Sigmoid** as using softmax was producing blank dark images.
# * The loss function in segnet is suggested **categorical crossentropy** due to it's genral use of multiclass segmentation problem but in our case we only have 1 class i.e. the melanoma. So, we will use **binary crossentropy**.

# %%
def segnet(epochs_num,savename):

    # Encoding layer
    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(learning_rate=0.001, momentum=0.9, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 16, validation_data= (x_val, y_val), verbose=1)
    
    model.save(savename)
    return model,hist

# %% [markdown]
# #### After 1 epoch

# %%
tf.keras.backend.clear_session()
model, hist = segnet(1, 'segnet_1_epoch.h5')
# Out:
# I0000 00:00:1742865483.720061  418453 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4096 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 192, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 192, 256, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn1 (BatchNormalization)        │ (None, 192, 256, 64)   │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn2 (BatchNormalization)        │ (None, 192, 256, 64)   │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn3 (BatchNormalization)        │ (None, 96, 128, 128)   │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn4 (BatchNormalization)        │ (None, 96, 128, 128)   │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5 (Conv2D)                  │ (None, 48, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn5 (BatchNormalization)        │ (None, 48, 64, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv6 (Conv2D)                  │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn6 (BatchNormalization)        │ (None, 48, 64, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv7 (Conv2D)                  │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn7 (BatchNormalization)        │ (None, 48, 64, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 24, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv8 (Conv2D)                  │ (None, 24, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn8 (BatchNormalization)        │ (None, 24, 32, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv9 (Conv2D)                  │ (None, 24, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn9 (BatchNormalization)        │ (None, 24, 32, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv10 (Conv2D)                 │ (None, 24, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn10 (BatchNormalization)       │ (None, 24, 32, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv11 (Conv2D)                 │ (None, 12, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn11 (BatchNormalization)       │ (None, 12, 16, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv12 (Conv2D)                 │ (None, 12, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn12 (BatchNormalization)       │ (None, 12, 16, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv13 (Conv2D)                 │ (None, 12, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn13 (BatchNormalization)       │ (None, 12, 16, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 6, 8, 1024)     │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 6, 8, 1024)     │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 12, 16, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv1 (Conv2DTranspose)       │ (None, 12, 16, 512)    │     4,719,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn14 (BatchNormalization)       │ (None, 12, 16, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv2 (Conv2DTranspose)       │ (None, 12, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn15 (BatchNormalization)       │ (None, 12, 16, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv3 (Conv2DTranspose)       │ (None, 12, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn16 (BatchNormalization)       │ (None, 12, 16, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 12, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv4 (Conv2DTranspose)       │ (None, 24, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn17 (BatchNormalization)       │ (None, 24, 32, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv5 (Conv2DTranspose)       │ (None, 24, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn18 (BatchNormalization)       │ (None, 24, 32, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv6 (Conv2DTranspose)       │ (None, 24, 32, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn19 (BatchNormalization)       │ (None, 24, 32, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 24, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv7 (Conv2DTranspose)       │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn20 (BatchNormalization)       │ (None, 48, 64, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv8 (Conv2DTranspose)       │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn21 (BatchNormalization)       │ (None, 48, 64, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv9 (Conv2DTranspose)       │ (None, 48, 64, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn22 (BatchNormalization)       │ (None, 48, 64, 128)    │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_3 (UpSampling2D)  │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv10 (Conv2DTranspose)      │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn23 (BatchNormalization)       │ (None, 96, 128, 128)   │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv11 (Conv2DTranspose)      │ (None, 96, 128, 64)    │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn24 (BatchNormalization)       │ (None, 96, 128, 64)    │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv12 (Conv2DTranspose)      │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn25 (BatchNormalization)       │ (None, 192, 256, 64)   │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_24 (Activation)      │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv13 (Conv2DTranspose)      │ (None, 192, 256, 1)    │           577 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn26 (BatchNormalization)       │ (None, 192, 256, 1)    │             4 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_25 (Activation)      │ (None, 192, 256, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 192, 256)       │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,393,669 (127.39 MB)
#  Trainable params: 33,377,795 (127.33 MB)
#  Non-trainable params: 15,874 (62.01 KB)
# I0000 00:00:1742865490.521179  418547 service.cc:148] XLA service 0x7fa0600150a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742865490.521255  418547 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-03-24 22:18:10.707723: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742865491.248712  418547 cuda_dnn.cc:529] Loaded cuDNN version 90800
# 2025-03-24 22:18:13.265983: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 56 bytes spill stores, 120 bytes spill loads
#
# 2025-03-24 22:18:13.318942: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 296 bytes spill stores, 272 bytes spill loads
#
# 2025-03-24 22:18:14.012590: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-03-24 22:18:14.044541: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 68 bytes spill stores, 68 bytes spill loads
#
# 2025-03-24 22:18:14.247071: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-03-24 22:18:14.422755: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 500 bytes spill stores, 448 bytes spill loads
#
# 2025-03-24 22:18:14.481335: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 104 bytes spill stores, 104 bytes spill loads
#
# E0000 00:00:1742865494.646237  418547 buffer_comparator.cc:157] Difference at 16: 0, expected 515.552
# E0000 00:00:1742865494.646359  418547 buffer_comparator.cc:157] Difference at 17: 0, expected 513.216
# E0000 00:00:1742865494.646365  418547 buffer_comparator.cc:157] Difference at 18: 0, expected 508.537
# E0000 00:00:1742865494.646366  418547 buffer_comparator.cc:157] Difference at 19: 0, expected 519.009
# E0000 00:00:1742865494.646368  418547 buffer_comparator.cc:157] Difference at 20: 0, expected 509.175
# E0000 00:00:1742865494.646369  418547 buffer_comparator.cc:157] Difference at 21: 0, expected 504.617
# E0000 00:00:1742865494.646372  418547 buffer_comparator.cc:157] Difference at 22: 0, expected 505.093
# E0000 00:00:1742865494.646374  418547 buffer_comparator.cc:157] Difference at 23: 0, expected 509.426
# E0000 00:00:1742865494.646375  418547 buffer_comparator.cc:157] Difference at 24: 0, expected 517.619
# E0000 00:00:1742865494.646377  418547 buffer_comparator.cc:157] Difference at 25: 0, expected 504.97
# 2025-03-24 22:18:14.646404: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.709335  418547 buffer_comparator.cc:157] Difference at 16: 0, expected 515.552
# E0000 00:00:1742865494.709409  418547 buffer_comparator.cc:157] Difference at 17: 0, expected 513.216
# E0000 00:00:1742865494.709414  418547 buffer_comparator.cc:157] Difference at 18: 0, expected 508.537
# E0000 00:00:1742865494.709416  418547 buffer_comparator.cc:157] Difference at 19: 0, expected 519.009
# E0000 00:00:1742865494.709417  418547 buffer_comparator.cc:157] Difference at 20: 0, expected 509.175
# E0000 00:00:1742865494.709419  418547 buffer_comparator.cc:157] Difference at 21: 0, expected 504.617
# E0000 00:00:1742865494.709420  418547 buffer_comparator.cc:157] Difference at 22: 0, expected 505.093
# E0000 00:00:1742865494.709422  418547 buffer_comparator.cc:157] Difference at 23: 0, expected 509.426
# E0000 00:00:1742865494.709423  418547 buffer_comparator.cc:157] Difference at 24: 0, expected 517.619
# E0000 00:00:1742865494.709424  418547 buffer_comparator.cc:157] Difference at 25: 0, expected 504.97
# 2025-03-24 22:18:14.709437: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.776342  418547 buffer_comparator.cc:157] Difference at 16: 0, expected 515.552
# E0000 00:00:1742865494.776412  418547 buffer_comparator.cc:157] Difference at 17: 0, expected 513.216
# E0000 00:00:1742865494.776417  418547 buffer_comparator.cc:157] Difference at 18: 0, expected 508.537
# E0000 00:00:1742865494.776419  418547 buffer_comparator.cc:157] Difference at 19: 0, expected 519.009
# E0000 00:00:1742865494.776420  418547 buffer_comparator.cc:157] Difference at 20: 0, expected 509.175
# E0000 00:00:1742865494.776422  418547 buffer_comparator.cc:157] Difference at 21: 0, expected 504.617
# E0000 00:00:1742865494.776423  418547 buffer_comparator.cc:157] Difference at 22: 0, expected 505.093
# E0000 00:00:1742865494.776425  418547 buffer_comparator.cc:157] Difference at 23: 0, expected 509.426
# E0000 00:00:1742865494.776426  418547 buffer_comparator.cc:157] Difference at 24: 0, expected 517.619
# E0000 00:00:1742865494.776428  418547 buffer_comparator.cc:157] Difference at 25: 0, expected 504.97
# 2025-03-24 22:18:14.776438: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.816967  418547 buffer_comparator.cc:157] Difference at 64: 0, expected 509.031
# E0000 00:00:1742865494.817041  418547 buffer_comparator.cc:157] Difference at 65: 0, expected 514.135
# E0000 00:00:1742865494.817046  418547 buffer_comparator.cc:157] Difference at 66: 0, expected 506.553
# E0000 00:00:1742865494.817048  418547 buffer_comparator.cc:157] Difference at 67: 0, expected 501.534
# E0000 00:00:1742865494.817049  418547 buffer_comparator.cc:157] Difference at 68: 0, expected 510.589
# E0000 00:00:1742865494.817051  418547 buffer_comparator.cc:157] Difference at 69: 0, expected 504.186
# E0000 00:00:1742865494.817052  418547 buffer_comparator.cc:157] Difference at 70: 0, expected 511.581
# E0000 00:00:1742865494.817054  418547 buffer_comparator.cc:157] Difference at 71: 0, expected 502.603
# E0000 00:00:1742865494.817055  418547 buffer_comparator.cc:157] Difference at 72: 0, expected 503.738
# E0000 00:00:1742865494.817056  418547 buffer_comparator.cc:157] Difference at 73: 0, expected 504.389
# 2025-03-24 22:18:14.817067: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.853511  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.853569  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.853574  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.853576  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.853577  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.853579  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.853580  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.853582  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.853583  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.853585  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.853593: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.863203  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.863264  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.863269  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.863270  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.863272  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.863273  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.863275  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.863276  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.863278  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.863279  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.863289: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.869131  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.869179  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.869184  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.869186  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.869187  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.869189  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.869190  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.869192  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.869193  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.869195  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.869204: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.874827  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.874867  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.874872  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.874874  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.874875  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.874877  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.874878  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.874880  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.874881  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.874882  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.874890: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.880907  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.880949  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.880954  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.880956  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.880957  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.880959  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.880960  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.880962  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.880964  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.880965  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.880972: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.886625  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.886663  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.886668  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.886670  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.886671  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.886673  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.886674  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.886676  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.886678  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.886679  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.886686: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.892436  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.892476  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.892481  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.892483  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.892484  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.892486  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.892487  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.892489  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.892490  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.892492  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.892498: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.898775  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.898812  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.898818  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.898819  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.898821  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.898822  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.898824  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.898825  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.898827  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.898828  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.898835: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.904167  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.904202  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.904208  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.904209  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.904211  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.904212  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.904214  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.904215  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.904217  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.904218  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.904226: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.909578  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.909614  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.909620  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.909621  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.909623  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.909624  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.909626  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.909627  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.909629  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.909630  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.909637: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.915785  418547 buffer_comparator.cc:157] Difference at 128: 0, expected 516.754
# E0000 00:00:1742865494.915819  418547 buffer_comparator.cc:157] Difference at 129: 0, expected 502.708
# E0000 00:00:1742865494.915824  418547 buffer_comparator.cc:157] Difference at 130: 0, expected 505.189
# E0000 00:00:1742865494.915825  418547 buffer_comparator.cc:157] Difference at 131: 0, expected 495.303
# E0000 00:00:1742865494.915827  418547 buffer_comparator.cc:157] Difference at 132: 0, expected 503.195
# E0000 00:00:1742865494.915828  418547 buffer_comparator.cc:157] Difference at 133: 0, expected 492.496
# E0000 00:00:1742865494.915830  418547 buffer_comparator.cc:157] Difference at 134: 0, expected 510.352
# E0000 00:00:1742865494.915831  418547 buffer_comparator.cc:157] Difference at 135: 0, expected 495.086
# E0000 00:00:1742865494.915833  418547 buffer_comparator.cc:157] Difference at 136: 0, expected 510.886
# E0000 00:00:1742865494.915834  418547 buffer_comparator.cc:157] Difference at 137: 0, expected 500.523
# 2025-03-24 22:18:14.915840: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.922906  418547 buffer_comparator.cc:157] Difference at 16: -nan, expected 133.89
# E0000 00:00:1742865494.922949  418547 buffer_comparator.cc:157] Difference at 17: -nan, expected 135.339
# E0000 00:00:1742865494.922954  418547 buffer_comparator.cc:157] Difference at 18: -nan, expected 131.494
# E0000 00:00:1742865494.922955  418547 buffer_comparator.cc:157] Difference at 19: -nan, expected 130.182
# E0000 00:00:1742865494.922957  418547 buffer_comparator.cc:157] Difference at 20: -nan, expected 133.768
# E0000 00:00:1742865494.922958  418547 buffer_comparator.cc:157] Difference at 21: -nan, expected 129.04
# E0000 00:00:1742865494.922960  418547 buffer_comparator.cc:157] Difference at 22: -nan, expected 134.995
# E0000 00:00:1742865494.922961  418547 buffer_comparator.cc:157] Difference at 23: -nan, expected 132.806
# E0000 00:00:1742865494.922963  418547 buffer_comparator.cc:157] Difference at 24: -nan, expected 137.931
# E0000 00:00:1742865494.922964  418547 buffer_comparator.cc:157] Difference at 25: -nan, expected 132.906
# 2025-03-24 22:18:14.922971: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.929687  418547 buffer_comparator.cc:157] Difference at 16: -nan, expected 133.89
# E0000 00:00:1742865494.929736  418547 buffer_comparator.cc:157] Difference at 17: -nan, expected 135.339
# E0000 00:00:1742865494.929741  418547 buffer_comparator.cc:157] Difference at 18: -nan, expected 131.494
# E0000 00:00:1742865494.929742  418547 buffer_comparator.cc:157] Difference at 19: -nan, expected 130.182
# E0000 00:00:1742865494.929744  418547 buffer_comparator.cc:157] Difference at 20: -nan, expected 133.768
# E0000 00:00:1742865494.929745  418547 buffer_comparator.cc:157] Difference at 21: -nan, expected 129.04
# E0000 00:00:1742865494.929747  418547 buffer_comparator.cc:157] Difference at 22: -nan, expected 134.995
# E0000 00:00:1742865494.929748  418547 buffer_comparator.cc:157] Difference at 23: -nan, expected 132.806
# E0000 00:00:1742865494.929764  418547 buffer_comparator.cc:157] Difference at 24: -nan, expected 137.931
# E0000 00:00:1742865494.929765  418547 buffer_comparator.cc:157] Difference at 25: -nan, expected 132.906
# 2025-03-24 22:18:14.929773: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.936415  418547 buffer_comparator.cc:157] Difference at 16: -nan, expected 133.89
# E0000 00:00:1742865494.936466  418547 buffer_comparator.cc:157] Difference at 17: -nan, expected 135.339
# E0000 00:00:1742865494.936471  418547 buffer_comparator.cc:157] Difference at 18: -nan, expected 131.494
# E0000 00:00:1742865494.936473  418547 buffer_comparator.cc:157] Difference at 19: -nan, expected 130.182
# E0000 00:00:1742865494.936474  418547 buffer_comparator.cc:157] Difference at 20: -nan, expected 133.768
# E0000 00:00:1742865494.936476  418547 buffer_comparator.cc:157] Difference at 21: -nan, expected 129.04
# E0000 00:00:1742865494.936477  418547 buffer_comparator.cc:157] Difference at 22: -nan, expected 134.995
# E0000 00:00:1742865494.936478  418547 buffer_comparator.cc:157] Difference at 23: -nan, expected 132.806
# E0000 00:00:1742865494.936480  418547 buffer_comparator.cc:157] Difference at 24: -nan, expected 137.931
# E0000 00:00:1742865494.936481  418547 buffer_comparator.cc:157] Difference at 25: -nan, expected 132.906
# 2025-03-24 22:18:14.936489: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.940663  418547 buffer_comparator.cc:157] Difference at 64: -nan, expected 135.918
# E0000 00:00:1742865494.940702  418547 buffer_comparator.cc:157] Difference at 65: -nan, expected 129.291
# E0000 00:00:1742865494.940707  418547 buffer_comparator.cc:157] Difference at 66: -nan, expected 136.884
# E0000 00:00:1742865494.940709  418547 buffer_comparator.cc:157] Difference at 67: -nan, expected 131.142
# E0000 00:00:1742865494.940711  418547 buffer_comparator.cc:157] Difference at 68: -nan, expected 138.266
# E0000 00:00:1742865494.940712  418547 buffer_comparator.cc:157] Difference at 69: -nan, expected 131.924
# E0000 00:00:1742865494.940714  418547 buffer_comparator.cc:157] Difference at 70: -nan, expected 134.647
# E0000 00:00:1742865494.940718  418547 buffer_comparator.cc:157] Difference at 71: -nan, expected 126.888
# E0000 00:00:1742865494.940719  418547 buffer_comparator.cc:157] Difference at 72: -nan, expected 131.11
# E0000 00:00:1742865494.940721  418547 buffer_comparator.cc:157] Difference at 73: -nan, expected 129.97
# 2025-03-24 22:18:14.940733: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.945891  418547 buffer_comparator.cc:157] Difference at 64: -nan, expected 135.918
# E0000 00:00:1742865494.945935  418547 buffer_comparator.cc:157] Difference at 65: -nan, expected 129.291
# E0000 00:00:1742865494.945940  418547 buffer_comparator.cc:157] Difference at 66: -nan, expected 136.884
# E0000 00:00:1742865494.945942  418547 buffer_comparator.cc:157] Difference at 67: -nan, expected 131.142
# E0000 00:00:1742865494.945943  418547 buffer_comparator.cc:157] Difference at 68: -nan, expected 138.266
# E0000 00:00:1742865494.945944  418547 buffer_comparator.cc:157] Difference at 69: -nan, expected 131.924
# E0000 00:00:1742865494.945946  418547 buffer_comparator.cc:157] Difference at 70: -nan, expected 134.647
# E0000 00:00:1742865494.945947  418547 buffer_comparator.cc:157] Difference at 71: -nan, expected 126.888
# E0000 00:00:1742865494.945949  418547 buffer_comparator.cc:157] Difference at 72: -nan, expected 131.11
# E0000 00:00:1742865494.945950  418547 buffer_comparator.cc:157] Difference at 73: -nan, expected 129.97
# 2025-03-24 22:18:14.945958: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.950093  418547 buffer_comparator.cc:157] Difference at 128: -nan, expected 133.42
# E0000 00:00:1742865494.950131  418547 buffer_comparator.cc:157] Difference at 129: -nan, expected 133.622
# E0000 00:00:1742865494.950136  418547 buffer_comparator.cc:157] Difference at 130: -nan, expected 131.967
# E0000 00:00:1742865494.950137  418547 buffer_comparator.cc:157] Difference at 131: -nan, expected 130.935
# E0000 00:00:1742865494.950139  418547 buffer_comparator.cc:157] Difference at 132: -nan, expected 131.556
# E0000 00:00:1742865494.950140  418547 buffer_comparator.cc:157] Difference at 133: -nan, expected 134.388
# E0000 00:00:1742865494.950141  418547 buffer_comparator.cc:157] Difference at 134: -nan, expected 131.109
# E0000 00:00:1742865494.950143  418547 buffer_comparator.cc:157] Difference at 135: -nan, expected 134.677
# E0000 00:00:1742865494.950144  418547 buffer_comparator.cc:157] Difference at 136: -nan, expected 127.126
# E0000 00:00:1742865494.950146  418547 buffer_comparator.cc:157] Difference at 137: -nan, expected 137.578
# 2025-03-24 22:18:14.950152: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.956088  418547 buffer_comparator.cc:157] Difference at 128: -nan, expected 133.42
# E0000 00:00:1742865494.956128  418547 buffer_comparator.cc:157] Difference at 129: -nan, expected 133.622
# E0000 00:00:1742865494.956133  418547 buffer_comparator.cc:157] Difference at 130: -nan, expected 131.967
# E0000 00:00:1742865494.956135  418547 buffer_comparator.cc:157] Difference at 131: -nan, expected 130.935
# E0000 00:00:1742865494.956136  418547 buffer_comparator.cc:157] Difference at 132: -nan, expected 131.556
# E0000 00:00:1742865494.956138  418547 buffer_comparator.cc:157] Difference at 133: -nan, expected 134.388
# E0000 00:00:1742865494.956139  418547 buffer_comparator.cc:157] Difference at 134: -nan, expected 131.109
# E0000 00:00:1742865494.956140  418547 buffer_comparator.cc:157] Difference at 135: -nan, expected 134.677
# E0000 00:00:1742865494.956142  418547 buffer_comparator.cc:157] Difference at 136: -nan, expected 127.126
# E0000 00:00:1742865494.956143  418547 buffer_comparator.cc:157] Difference at 137: -nan, expected 137.578
# 2025-03-24 22:18:14.956149: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.960797  418547 buffer_comparator.cc:157] Difference at 128: -nan, expected 133.42
# E0000 00:00:1742865494.960841  418547 buffer_comparator.cc:157] Difference at 129: -nan, expected 133.622
# E0000 00:00:1742865494.960846  418547 buffer_comparator.cc:157] Difference at 130: -nan, expected 131.967
# E0000 00:00:1742865494.960847  418547 buffer_comparator.cc:157] Difference at 131: -nan, expected 130.935
# E0000 00:00:1742865494.960849  418547 buffer_comparator.cc:157] Difference at 132: -nan, expected 131.556
# E0000 00:00:1742865494.960850  418547 buffer_comparator.cc:157] Difference at 133: -nan, expected 134.388
# E0000 00:00:1742865494.960852  418547 buffer_comparator.cc:157] Difference at 134: -nan, expected 131.109
# E0000 00:00:1742865494.960853  418547 buffer_comparator.cc:157] Difference at 135: -nan, expected 134.677
# E0000 00:00:1742865494.960855  418547 buffer_comparator.cc:157] Difference at 136: -nan, expected 127.126
# E0000 00:00:1742865494.960856  418547 buffer_comparator.cc:157] Difference at 137: -nan, expected 137.578
# 2025-03-24 22:18:14.960861: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.965737  418547 buffer_comparator.cc:157] Difference at 128: -nan, expected 133.42
# E0000 00:00:1742865494.965776  418547 buffer_comparator.cc:157] Difference at 129: -nan, expected 133.622
# E0000 00:00:1742865494.965781  418547 buffer_comparator.cc:157] Difference at 130: -nan, expected 131.967
# E0000 00:00:1742865494.965783  418547 buffer_comparator.cc:157] Difference at 131: -nan, expected 130.935
# E0000 00:00:1742865494.965784  418547 buffer_comparator.cc:157] Difference at 132: -nan, expected 131.556
# E0000 00:00:1742865494.965786  418547 buffer_comparator.cc:157] Difference at 133: -nan, expected 134.388
# E0000 00:00:1742865494.965787  418547 buffer_comparator.cc:157] Difference at 134: -nan, expected 131.109
# E0000 00:00:1742865494.965789  418547 buffer_comparator.cc:157] Difference at 135: -nan, expected 134.677
# E0000 00:00:1742865494.965790  418547 buffer_comparator.cc:157] Difference at 136: -nan, expected 127.126
# E0000 00:00:1742865494.965791  418547 buffer_comparator.cc:157] Difference at 137: -nan, expected 137.578
# 2025-03-24 22:18:14.965797: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.969740  418547 buffer_comparator.cc:157] Difference at 128: -nan, expected 133.42
# E0000 00:00:1742865494.969776  418547 buffer_comparator.cc:157] Difference at 129: -nan, expected 133.622
# E0000 00:00:1742865494.969781  418547 buffer_comparator.cc:157] Difference at 130: -nan, expected 131.967
# E0000 00:00:1742865494.969783  418547 buffer_comparator.cc:157] Difference at 131: -nan, expected 130.935
# E0000 00:00:1742865494.969784  418547 buffer_comparator.cc:157] Difference at 132: -nan, expected 131.556
# E0000 00:00:1742865494.969786  418547 buffer_comparator.cc:157] Difference at 133: -nan, expected 134.388
# E0000 00:00:1742865494.969787  418547 buffer_comparator.cc:157] Difference at 134: -nan, expected 131.109
# E0000 00:00:1742865494.969788  418547 buffer_comparator.cc:157] Difference at 135: -nan, expected 134.677
# E0000 00:00:1742865494.969790  418547 buffer_comparator.cc:157] Difference at 136: -nan, expected 127.126
# E0000 00:00:1742865494.969791  418547 buffer_comparator.cc:157] Difference at 137: -nan, expected 137.578
# 2025-03-24 22:18:14.969796: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865494.973609  418547 buffer_comparator.cc:157] Difference at 128: -nan, expected 133.42
# E0000 00:00:1742865494.973646  418547 buffer_comparator.cc:157] Difference at 129: -nan, expected 133.622
# ...
# E0000 00:00:1742865498.706461  418547 buffer_comparator.cc:157] Difference at 260: 0, expected 4.90875
# E0000 00:00:1742865498.706463  418547 buffer_comparator.cc:157] Difference at 261: 0, expected 4.20931
# E0000 00:00:1742865498.706464  418547 buffer_comparator.cc:157] Difference at 262: 0, expected 5.84689
# E0000 00:00:1742865498.706466  418547 buffer_comparator.cc:157] Difference at 263: 0, expected 3.87307
# E0000 00:00:1742865498.706467  418547 buffer_comparator.cc:157] Difference at 264: 0, expected 5.2736
# E0000 00:00:1742865498.706469  418547 buffer_comparator.cc:157] Difference at 265: 0, expected 3.72849
# 2025-03-24 22:18:18.708415: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865498.881971  418547 buffer_comparator.cc:157] Difference at 256: 0, expected 4.40524
# E0000 00:00:1742865498.882153  418547 buffer_comparator.cc:157] Difference at 257: 0, expected 5.22381
# E0000 00:00:1742865498.882170  418547 buffer_comparator.cc:157] Difference at 258: 0, expected 5.93825
# E0000 00:00:1742865498.882172  418547 buffer_comparator.cc:157] Difference at 259: 0, expected 6.51077
# E0000 00:00:1742865498.882173  418547 buffer_comparator.cc:157] Difference at 260: 0, expected 4.90875
# E0000 00:00:1742865498.882175  418547 buffer_comparator.cc:157] Difference at 261: 0, expected 4.20931
# E0000 00:00:1742865498.882176  418547 buffer_comparator.cc:157] Difference at 262: 0, expected 5.84689
# E0000 00:00:1742865498.882177  418547 buffer_comparator.cc:157] Difference at 263: 0, expected 3.87307
# E0000 00:00:1742865498.882179  418547 buffer_comparator.cc:157] Difference at 264: 0, expected 5.2736
# E0000 00:00:1742865498.882180  418547 buffer_comparator.cc:157] Difference at 265: 0, expected 3.72849
# 2025-03-24 22:18:18.884086: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865499.054411  418547 buffer_comparator.cc:157] Difference at 256: 0, expected 4.40524
# E0000 00:00:1742865499.054483  418547 buffer_comparator.cc:157] Difference at 257: 0, expected 5.22381
# E0000 00:00:1742865499.054488  418547 buffer_comparator.cc:157] Difference at 258: 0, expected 5.93825
# E0000 00:00:1742865499.054490  418547 buffer_comparator.cc:157] Difference at 259: 0, expected 6.51077
# E0000 00:00:1742865499.054491  418547 buffer_comparator.cc:157] Difference at 260: 0, expected 4.90875
# E0000 00:00:1742865499.054492  418547 buffer_comparator.cc:157] Difference at 261: 0, expected 4.20931
# E0000 00:00:1742865499.054494  418547 buffer_comparator.cc:157] Difference at 262: 0, expected 5.84689
# E0000 00:00:1742865499.054495  418547 buffer_comparator.cc:157] Difference at 263: 0, expected 3.87307
# E0000 00:00:1742865499.054497  418547 buffer_comparator.cc:157] Difference at 264: 0, expected 5.2736
# E0000 00:00:1742865499.054498  418547 buffer_comparator.cc:157] Difference at 265: 0, expected 3.72849
# 2025-03-24 22:18:19.056130: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865499.228561  418547 buffer_comparator.cc:157] Difference at 256: 0, expected 4.40524
# E0000 00:00:1742865499.228635  418547 buffer_comparator.cc:157] Difference at 257: 0, expected 5.22381
# E0000 00:00:1742865499.228640  418547 buffer_comparator.cc:157] Difference at 258: 0, expected 5.93825
# E0000 00:00:1742865499.228642  418547 buffer_comparator.cc:157] Difference at 259: 0, expected 6.51077
# E0000 00:00:1742865499.228643  418547 buffer_comparator.cc:157] Difference at 260: 0, expected 4.90875
# E0000 00:00:1742865499.228644  418547 buffer_comparator.cc:157] Difference at 261: 0, expected 4.20931
# E0000 00:00:1742865499.228646  418547 buffer_comparator.cc:157] Difference at 262: 0, expected 5.84689
# E0000 00:00:1742865499.228647  418547 buffer_comparator.cc:157] Difference at 263: 0, expected 3.87307
# E0000 00:00:1742865499.228649  418547 buffer_comparator.cc:157] Difference at 264: 0, expected 5.2736
# E0000 00:00:1742865499.228650  418547 buffer_comparator.cc:157] Difference at 265: 0, expected 3.72849
# 2025-03-24 22:18:19.230688: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# E0000 00:00:1742865499.411105  418547 buffer_comparator.cc:157] Difference at 256: 0, expected 4.40524
# E0000 00:00:1742865499.411176  418547 buffer_comparator.cc:157] Difference at 257: 0, expected 5.22381
# E0000 00:00:1742865499.411181  418547 buffer_comparator.cc:157] Difference at 258: 0, expected 5.93825
# E0000 00:00:1742865499.411182  418547 buffer_comparator.cc:157] Difference at 259: 0, expected 6.51077
# E0000 00:00:1742865499.411184  418547 buffer_comparator.cc:157] Difference at 260: 0, expected 4.90875
# E0000 00:00:1742865499.411185  418547 buffer_comparator.cc:157] Difference at 261: 0, expected 4.20931
# E0000 00:00:1742865499.411186  418547 buffer_comparator.cc:157] Difference at 262: 0, expected 5.84689
# E0000 00:00:1742865499.411188  418547 buffer_comparator.cc:157] Difference at 263: 0, expected 3.87307
# E0000 00:00:1742865499.411189  418547 buffer_comparator.cc:157] Difference at 264: 0, expected 5.2736
# E0000 00:00:1742865499.411190  418547 buffer_comparator.cc:157] Difference at 265: 0, expected 3.72849
# 2025-03-24 22:18:19.413151: E external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:987] Results do not match the reference. This is likely a bug/unexpected loss of precision.
# 2025-03-24 22:18:21.429365: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:22.355475: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:22.982047: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.33GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:23.761597: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.65GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:24.157914: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:24.893881: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:40.411297: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.55GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:42.038133: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:42.924736: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.33GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:44.447620: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.65GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-24 22:18:59.622945: W external/local_xla/xla/service/hlo_rematerialization.cc:3005] Can't reduce memory use below 2.80GiB (3004813088 bytes) by rematerialization; only reduced to 2.82GiB (3025618283 bytes), down from 3.23GiB (3465708104 bytes) originally
# I0000 00:00:1742865543.330619  418547 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 tf.keras.backend.clear_session()
# ----> 2 model, hist = segnet(1, 'segnet_1_epoch.h5')
#
# Cell In[24], line 112, in segnet(epochs_num, savename)
#     109 model.compile(optimizer= SGD(learning_rate=0.001, momentum=0.9, nesterov=False), loss= ["binary_crossentropy"]
#     110               , metrics=[iou, dice_coef, precision, recall, accuracy])
#     111 model.summary()
# --> 112 hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 16, validation_data= (x_val, y_val), verbose=1)
#     114 model.save(savename)
#     115 return model,hist
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     913   # If we did not create any variables the trace we have is good enough.
#     914   filtered_flat_args = (
#     915       self._concrete_variable_creation_fn.function_type.unpack_inputs(
#     916           bound_args
#     917       )
#     918   )
# --> 919   return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920       filtered_flat_args,
#     921       self._concrete_variable_creation_fn.captured_inputs,
#     922   )
#     924 def fn_with_cond(inner_args, inner_kwds):
#     925   """Conditionally runs initialization if it's needed."""
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~/anaconda3/envs/last/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Loading the Model

# %% [markdown]
# Here we can load a pre-trained model

# %%
# Encoding layer
img_input = Input(shape= (192, 256, 3))
x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
x = BatchNormalization(name='bn9')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
x = BatchNormalization(name='bn10')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
x = BatchNormalization(name='bn11')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
x = BatchNormalization(name='bn12')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
x = BatchNormalization(name='bn13')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)
# Decoding Layer 
x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn14')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn15')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn16')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn17')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
x = BatchNormalization(name='bn18')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
x = BatchNormalization(name='bn19')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
x = BatchNormalization(name='bn20')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
x = BatchNormalization(name='bn21')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
x = BatchNormalization(name='bn22')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
x = BatchNormalization(name='bn23')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
x = BatchNormalization(name='bn24')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
x = BatchNormalization(name='bn25')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
x = BatchNormalization(name='bn26')(x)
x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
tf.keras.backend.clear_session()
model_0 = Model(inputs=img_input, outputs=pred)

model_0.compile(optimizer= tf.keras.optimizers.legacy.SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_0.load_weights('segnet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = segnet(epochs_num= 100, savename= 'segnet_100_epoch.h5')

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= tf.keras.optimizers.legacy.SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_1.load_weights('segnet_100_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# ### Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_0.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ### Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.2 .
# * While rounding down the pixel values to 0 which are < 0.2.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.2:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[19],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[19]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too

# %% [markdown]
# ### *de nada!*
